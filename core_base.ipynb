# %%
import pandas as pd

df = pd.read_csv("butun-nov-trvz-ehtiyatlar-dt_cd_019.csv",delimiter=",")
df
# Out:
#     Year  Unnamed: 1  İlin əvvəlinə qalıq (ton)  İstehsal (ton)  İdxal (ton)  \
# 0   2024         NaN                   318354.0       1838903.0      80475.0
# 1   2023         NaN                   317893.0       1825592.0      58453.0
# 2   2022         NaN                   313037.0       1823330.0      54638.0
# 3   2021         NaN                   275222.0       1815512.0      63951.0
# 4   2020         NaN                   263922.0       1738860.0      56037.0
# 5   2019         NaN                   219804.0       1714678.0      39806.0
# 6   2018         NaN                   205223.0       1521931.0      36794.0
# 7   2017         NaN                   203338.0       1405619.0      45917.0
# 8   2016         NaN                   189282.0       1270622.0      61184.0
# 9   2015         NaN                   179484.0       1275257.0      41984.0
# 10  2014         NaN                   196990.0       1187681.0      38765.0
# 11  2013         NaN                   199515.0       1236331.0      37752.0
# 12  2012         NaN                   206299.0       1216240.0      69952.0
# 13  2011         NaN                   199434.0       1214758.0     121117.0
# 14  2010         NaN                   201800.0       1189465.0      84921.0
# 15  2009         NaN                   189938.0       1178595.0      50207.0
# 16  2008         NaN                   184520.0       1228312.0      26849.0
# 17  2007         NaN                   175509.0       1227350.0      68033.0
#
#     Ehtiyatların cəmi (ton)
# 0                 2237732.0
# 1                 2201938.0
# 2                 2191005.0
# 3                 2154685.0
# 4                 2058819.0
# 5                 1974288.0
# 6                 1763948.0
# 7                 1654874.0
# 8                 1521088.0
# 9                 1496725.0
# 10                1423436.0
# 11                1473598.0
# 12                1492491.0
# 13                1535309.0
# 14                1476186.0
# 15                1418740.0
# 16                1439681.0
# 17                1470892.0

# %%
df = df.drop(columns=['Unnamed: 1'])
df
# Out:
#     Year  İlin əvvəlinə qalıq (ton)  İstehsal (ton)  İdxal (ton)  \
# 0   2024                   318354.0       1838903.0      80475.0
# 1   2023                   317893.0       1825592.0      58453.0
# 2   2022                   313037.0       1823330.0      54638.0
# 3   2021                   275222.0       1815512.0      63951.0
# 4   2020                   263922.0       1738860.0      56037.0
# 5   2019                   219804.0       1714678.0      39806.0
# 6   2018                   205223.0       1521931.0      36794.0
# 7   2017                   203338.0       1405619.0      45917.0
# 8   2016                   189282.0       1270622.0      61184.0
# 9   2015                   179484.0       1275257.0      41984.0
# 10  2014                   196990.0       1187681.0      38765.0
# 11  2013                   199515.0       1236331.0      37752.0
# 12  2012                   206299.0       1216240.0      69952.0
# 13  2011                   199434.0       1214758.0     121117.0
# 14  2010                   201800.0       1189465.0      84921.0
# 15  2009                   189938.0       1178595.0      50207.0
# 16  2008                   184520.0       1228312.0      26849.0
# 17  2007                   175509.0       1227350.0      68033.0
#
#     Ehtiyatların cəmi (ton)
# 0                 2237732.0
# 1                 2201938.0
# 2                 2191005.0
# 3                 2154685.0
# 4                 2058819.0
# 5                 1974288.0
# 6                 1763948.0
# 7                 1654874.0
# 8                 1521088.0
# 9                 1496725.0
# 10                1423436.0
# 11                1473598.0
# 12                1492491.0
# 13                1535309.0
# 14                1476186.0
# 15                1418740.0
# 16                1439681.0
# 17                1470892.0

# %%
#Line chart
import matplotlib.pyplot as plt
plt.style.use("default")
plt.figure(figsize=(6.4, 4.8))
plt.grid(True)
plt.title("Production and Import Over Years")
plt.plot(df["Year"], df["İdxal (ton)"]/1_000_000,
         marker='o', color=(80/255, 26/255, 80/255, 0.8),
         label="Imported")

plt.plot(df["Year"], df["İstehsal (ton)"]/1_000_000,
         marker='o', color=(16/255, 112/255, 2/255, 0.8),
         label="Produced")
plt.xlabel("Years")
plt.xlim(df["Year"].min(), df["Year"].max())
plt.ylabel("Million Tons")
# plt.ylim(df["Tons"].min(), df["Tons"].max())
plt.legend(loc='upper left')
